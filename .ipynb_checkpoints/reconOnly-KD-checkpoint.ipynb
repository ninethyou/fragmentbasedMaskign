# %%
# !python Recon+predict.py \
--task_name freesolv \
--seed 446 \
--random_masking 1 \
--alpha 1 \
--mask_rate 0
# Out:
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# {'batch_size': 32, 'epochs': 200, 'eval_every_n_epochs': 1, 'fine_tune_from': 'pretrained_gin', 'log_every_n_steps': 50, 'fp16_precision': False, 'init_lr': 0.0005, 'init_base_lr': 0.0001, 'weight_decay': '1e-6', 'gpu': 'cuda:0', 'task_name': 'esol', 'model_type': 'gin', 'model': {'num_layer': 5, 'emb_dim': 300, 'feat_dim': 300, 'drop_ratio': 0.3, 'pool': 'mean'}, 'dataset': {'num_workers': 4, 'valid_size': 0.1, 'test_size': 0.1, 'splitting': 'scaffold', 'seed': 446, 'task': 'regression', 'data_path': 'data/esol/esol.csv', 'target': ['measured log solubility in mols per litre']}}
# Running on: cuda:0
# 1127
# About to generate scaffolds
# Generating scaffold 0/1127
# Generating scaffold 1000/1127
# About to sort in scaffold sets
# pred_head.0.weight True
# pred_head.0.bias True
# pred_head.2.weight True
# pred_head.2.bias True
# pred_head.4.weight True
# pred_head.4.bias True
# [8]
# [12]
# [2]
# ...

# %%
datasets = ['qm7', "bace",  "bbbp",  'tox21', 'clintox', 'sider',]
seeds = [777, 778, 779, 780, 781]


for dataset in datasets:
    for seed in seeds:
            if dataset == 'FreeSolv':
            # FreeSolv 데이터셋에 대한 특정 옵션을 적용
                # !python Recon+predict.py \
                --task_name {dataset} \
                --seed {seed} \
                --dropout 0.5 \
                --num_layer 3 \
                --emb_dim 64 \
                --feat_dim 64 \
                --alpha 1 \
                --mask_rate 0.2 \
                --gpu cuda:0 \
                --epochs 300
            
            elif dataset == 'clintox':
                # !python Recon+predict.py \
                --task_name {dataset} \
                --seed {seed} \
                --dropout 0.3 \
                --num_layer 5 \
                --emb_dim 64 \
                --feat_dim 64 \
                --alpha 1 \
                --mask_rate 0.2 \
                --gpu cuda:0 \
                --epochs 300

            elif dataset == 'esol':
                # !python Recon+predict.py \
                --task_name {dataset} \
                --seed {seed} \
                --alpha 1 \
                --gpu cuda:0 \
                --mask_rate 0.2 \
                --epochs 300
            elif dataset == 'lipo':
                # !python Recon+predict.py \
                --task_name {dataset} \
                --seed {seed} \
                --alpha 0.2 \
                --gpu cuda:0 \
                --mask_rate 0.2 \
                --epochs 300
            elif dataset == 'qm7':
                # !python Recon+predict.py \
                --task_name {dataset} \
                --seed {seed} \
                --alpha 0.5 \
                --gpu cuda:0 \
                --mask_rate 0.2 \
                --epochs 300
            else:
                # !python Recon+predict.py \
                --task_name {dataset} \
                --seed {seed} \
                --alpha 0.2 \
                --gpu cuda:0 \
                --mask_rate 0.2 \
                --epochs 300
# Out:
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# {'batch_size': 32, 'epochs': 300, 'eval_every_n_epochs': 1, 'fine_tune_from': 'pretrained_gin', 'log_every_n_steps': 50, 'fp16_precision': False, 'init_lr': 0.0005, 'init_base_lr': 0.0001, 'weight_decay': '1e-6', 'gpu': 'cuda:0', 'task_name': 'qm7', 'model_type': 'gin', 'model': {'num_layer': 5, 'emb_dim': 300, 'feat_dim': 300, 'drop_ratio': 0.3, 'pool': 'mean'}, 'dataset': {'num_workers': 4, 'valid_size': 0.1, 'test_size': 0.1, 'splitting': 'scaffold', 'seed': 777, 'task': 'regression', 'data_path': 'data/qm7/qm7.csv', 'target': ['u0_atom']}}
# Running on: cuda:0
# 6833
# About to generate scaffolds
# Generating scaffold 0/6833
# Generating scaffold 1000/6833
# Generating scaffold 2000/6833
# Generating scaffold 3000/6833
# Generating scaffold 4000/6833
# Generating scaffold 5000/6833
# Generating scaffold 6000/6833
# About to sort in scaffold sets
# ...

# %%
seeds = list(range(11,15))
for seed in seeds:
    # !python Recon+predict.py \
    --task_name qm7 \
    --seed {seed} \
    --alpha 0.2 \
    --gpu cuda:1 \
    --mask_rate 0.2 \
    --epochs 300
# Out:
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# {'batch_size': 32, 'epochs': 300, 'eval_every_n_epochs': 1, 'fine_tune_from': 'pretrained_gin', 'log_every_n_steps': 50, 'fp16_precision': False, 'init_lr': 0.0005, 'init_base_lr': 0.0001, 'weight_decay': '1e-6', 'gpu': 'cuda:1', 'task_name': 'qm7', 'model_type': 'gin', 'model': {'num_layer': 5, 'emb_dim': 300, 'feat_dim': 300, 'drop_ratio': 0.3, 'pool': 'mean'}, 'dataset': {'num_workers': 4, 'valid_size': 0.1, 'test_size': 0.1, 'splitting': 'scaffold', 'seed': 11, 'task': 'regression', 'data_path': 'data/qm7/qm7.csv', 'target': ['u0_atom']}}
# Running on: cuda:1
# 6833
# About to generate scaffolds
# Generating scaffold 0/6833
# Generating scaffold 1000/6833
# Generating scaffold 2000/6833
# Generating scaffold 3000/6833
# Generating scaffold 4000/6833
# Generating scaffold 5000/6833
# Generating scaffold 6000/6833
# About to sort in scaffold sets
# ...

# %%
seeds = list(range(20,25))

for seed in seeds:
    # !python Recon+predictKD.py \
    --task_name lipo \
    --seed {seed} \
    --alpha 0.1 \
    --gpu cuda:0 \
    --mask_rate 0.2
# Out:
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# {'batch_size': 32, 'epochs': 200, 'eval_every_n_epochs': 1, 'fine_tune_from': 'pretrained_gin', 'log_every_n_steps': 50, 'fp16_precision': False, 'init_lr': 0.0005, 'init_base_lr': 0.0001, 'weight_decay': '1e-6', 'gpu': 'cuda:0', 'task_name': 'lipo', 'model_type': 'gin', 'model': {'num_layer': 5, 'emb_dim': 300, 'feat_dim': 300, 'drop_ratio': 0.3, 'pool': 'mean'}, 'dataset': {'num_workers': 4, 'valid_size': 0.1, 'test_size': 0.1, 'splitting': 'scaffold', 'seed': 20, 'task': 'regression', 'data_path': 'data/lipophilicity/Lipophilicity.csv', 'target': ['exp']}}
# Running on: cuda:0
# 4199
# About to generate scaffolds
# Generating scaffold 0/4199
# Generating scaffold 1000/4199
# Generating scaffold 2000/4199
# Generating scaffold 3000/4199
# Generating scaffold 4000/4199
# About to sort in scaffold sets
# pred_head.0.weight True
# pred_head.0.bias True
# pred_head.2.weight True
# ...

# %%
# !python Recon+predictKD.py \
--task_name lipo \
--seed 450 \
--alpha 0.2 \
--gpu cuda:0 \
--mask_rate 0.2
# Out:
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# {'batch_size': 32, 'epochs': 200, 'eval_every_n_epochs': 1, 'fine_tune_from': 'pretrained_gin', 'log_every_n_steps': 50, 'fp16_precision': False, 'init_lr': 0.0005, 'init_base_lr': 0.0001, 'weight_decay': '1e-6', 'gpu': 'cuda:0', 'task_name': 'lipo', 'model_type': 'gin', 'model': {'num_layer': 5, 'emb_dim': 300, 'feat_dim': 300, 'drop_ratio': 0.3, 'pool': 'mean'}, 'dataset': {'num_workers': 4, 'valid_size': 0.1, 'test_size': 0.1, 'splitting': 'scaffold', 'seed': 450, 'task': 'regression', 'data_path': 'data/lipophilicity/Lipophilicity.csv', 'target': ['exp']}}
# Running on: cuda:0
# 4199
# About to generate scaffolds
# Generating scaffold 0/4199
# Generating scaffold 1000/4199
# Generating scaffold 2000/4199
# Generating scaffold 3000/4199
# Generating scaffold 4000/4199
# About to sort in scaffold sets
# pred_head.0.weight True
# pred_head.0.bias True
# pred_head.2.weight True
# ...
