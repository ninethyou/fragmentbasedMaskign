# %%
pwd
# Out:
# '/tf/MolCLR-master - 복사본 - 복사본'

# %%
datasets = ['FreeSolv', 'ESOL', 'Lipo', 'qm7', "bace",  "bbbp",  'tox21', 'clintox', 'sider',]
seeds = [777, 778, 779, 780, 781]

for dataset in datasets:
    for seed in seeds:
            if dataset == 'FreeSolv':
            # FreeSolv 데이터셋에 대한 특정 옵션을 적용
                # !python finetuneRich.py \
                --task_name {dataset} \
                --seed {seed} \
                --dropout 0.5 \
                --num_layer 3 \
                --emb_dim 64 \
                --feat_dim 64 \
                --gpu cuda:1 
                
            elif dataset == 'clintox':
                # !python finetuneRich.py \
                --task_name {dataset} \
                --seed {seed} \
                --emb_dim 64 \
                --feat_dim 64 \
                --alpha 0.1 \
                --gpu cuda:1 \
                
            else:
                # !python finetuneRich.py \
                --task_name {dataset} \
                --seed {seed} \
                --gpu cuda:1
# Out:
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# {'batch_size': 32, 'epochs': 200, 'eval_every_n_epochs': 1, 'fine_tune_from': 'pretrained_gin', 'log_every_n_steps': 50, 'fp16_precision': False, 'init_lr': 0.0005, 'init_base_lr': 0.0001, 'weight_decay': '1e-6', 'gpu': 'cuda:1', 'task_name': 'freesolv', 'model_type': 'gin', 'model': {'num_layer': 3, 'emb_dim': 64, 'feat_dim': 64, 'drop_ratio': 0.5, 'pool': 'mean'}, 'dataset': {'num_workers': 4, 'valid_size': 0.1, 'test_size': 0.1, 'splitting': 'scaffold', 'seed': 777, 'task': 'regression', 'data_path': 'data/freesolv/freesolv.csv', 'target': ['expt']}}
# Running on: cuda:1
# 641
# About to generate scaffolds
# Generating scaffold 0/641
# About to sort in scaffold sets
# pred_head.0.weight True
# pred_head.0.bias True
# pred_head.2.weight True
# pred_head.2.bias True
# pred_head.4.weight True
# pred_head.4.bias True
# 0 0 16.819332122802734
# Validation loss: 61.47366142272949 RMSE: 7.840514
# Validation loss: 56.484718322753906 RMSE: 7.5156317
# Validation loss: 49.615745544433594 RMSE: 7.0438447
# 3 2 9.095367431640625
# Validation loss: 40.4255256652832 RMSE: 6.3581076
# Validation loss: 25.44144058227539 RMSE: 5.043951
# Validation loss: 25.92257022857666 RMSE: 5.091421
# 6 4 8.08138656616211
# Validation loss: 22.62490463256836 RMSE: 4.7565646
# Validation loss: 15.608182907104492 RMSE: 3.9507194
# Validation loss: 13.272412776947021 RMSE: 3.6431324
# 9 6 5.512304782867432
# Validation loss: 11.962408542633057 RMSE: 3.4586713
# Validation loss: 8.324943542480469 RMSE: 2.8852978
# Validation loss: 8.37015676498413 RMSE: 2.8931222
# 12 8 4.100133895874023
# Validation loss: 8.881565570831299 RMSE: 2.9801955
# Validation loss: 10.001039981842041 RMSE: 3.1624422
# Validation loss: 8.596543312072754 RMSE: 2.931986
# 15 10 4.801827907562256
# Validation loss: 9.087677955627441 RMSE: 3.0145774
# Validation loss: 5.864564418792725 RMSE: 2.4216862
# Validation loss: 6.1311211585998535 RMSE: 2.47611
# 18 12 4.738779067993164
# Validation loss: 7.755633354187012 RMSE: 2.784894
# Validation loss: 6.522936105728149 RMSE: 2.554004
# Validation loss: 6.985675811767578 RMSE: 2.6430428
# 165 10 0.6112625598907471
# Validation loss: 8.579360008239746 RMSE: 2.9290543
# Validation loss: 7.0040833950042725 RMSE: 2.646523
# Validation loss: 6.090612888336182 RMSE: 2.4679167
# 168 12 1.981953501701355
# Validation loss: 6.946352481842041 RMSE: 2.6355934
# Validation loss: 9.553191661834717 RMSE: 3.090824
# Validation loss: 8.163920879364014 RMSE: 2.8572576
# 171 14 1.0339051485061646
# Validation loss: 6.502126932144165 RMSE: 2.549927
# Validation loss: 8.110123634338379 RMSE: 2.847828
# Validation loss: 7.37007999420166 RMSE: 2.7147892
# Validation loss: 5.335566520690918 RMSE: 2.3098845
# 175 0 1.9115443229675293
# Validation loss: 8.05651330947876 RMSE: 2.8384001
# Validation loss: 7.158438444137573 RMSE: 2.675526
# Validation loss: 8.596625328063965 RMSE: 2.9320004
# 178 2 2.135885715484619
# Validation loss: 6.08108377456665 RMSE: 2.4659853
# Validation loss: 6.169272422790527 RMSE: 2.483802
# Validation loss: 7.382029056549072 RMSE: 2.716989
# 181 4 5.802115440368652
# Validation loss: 8.559180974960327 RMSE: 2.925608
# Validation loss: 7.7527852058410645 RMSE: 2.7843823
# Validation loss: 8.841608047485352 RMSE: 2.9734843
# 184 6 0.9539950489997864
# Validation loss: 8.307295083999634 RMSE: 2.882238
# Validation loss: 8.888018608093262 RMSE: 2.981278
# Validation loss: 9.595799922943115 RMSE: 3.097709
# 187 8 2.866699457168579
# Validation loss: 6.682566165924072 RMSE: 2.585066
# Validation loss: 6.966649293899536 RMSE: 2.6394413
# Validation loss: 8.901795625686646 RMSE: 2.9835875
# 190 10 0.5903522372245789
# Validation loss: 9.03218412399292 RMSE: 3.0053592
# Validation loss: 7.073049545288086 RMSE: 2.6595204
# Validation loss: 8.401944637298584 RMSE: 2.8986108
# 193 12 1.507104754447937
# Validation loss: 7.524415016174316 RMSE: 2.7430668
# Validation loss: 9.78266954421997 RMSE: 3.127726
# Validation loss: 8.154680252075195 RMSE: 2.8556402
# 196 14 0.9745767712593079
# Validation loss: 7.318774223327637 RMSE: 2.7053232
# Validation loss: 8.577710151672363 RMSE: 2.9287727
# Validation loss: 8.322521209716797 RMSE: 2.884878
# Validation loss: 7.790217876434326 RMSE: 2.791096
# Loaded trained model with success.
# Test loss: 10.671537903638987 Test RMSE: 3.266732
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# {'batch_size': 32, 'epochs': 200, 'eval_every_n_epochs': 1, 'fine_tune_from': 'pretrained_gin', 'log_every_n_steps': 50, 'fp16_precision': False, 'init_lr': 0.0005, 'init_base_lr': 0.0001, 'weight_decay': '1e-6', 'gpu': 'cuda:1', 'task_name': 'freesolv', 'model_type': 'gin', 'model': {'num_layer': 3, 'emb_dim': 64, 'feat_dim': 64, 'drop_ratio': 0.5, 'pool': 'mean'}, 'dataset': {'num_workers': 4, 'valid_size': 0.1, 'test_size': 0.1, 'splitting': 'scaffold', 'seed': 778, 'task': 'regression', 'data_path': 'data/freesolv/freesolv.csv', 'target': ['expt']}}
# Running on: cuda:1
# 641
# About to generate scaffolds
# Generating scaffold 0/641
# About to sort in scaffold sets
# Validation loss: 6.70514178276062 RMSE: 2.589429
# 190 10 2.126542091369629
# Validation loss: 6.705408096313477 RMSE: 2.5894802
# Validation loss: 9.19667911529541 RMSE: 3.0326025
# Validation loss: 6.860544681549072 RMSE: 2.6192641
# 193 12 1.665966510772705
# Validation loss: 6.189180374145508 RMSE: 2.4878066
# Validation loss: 5.574795722961426 RMSE: 2.3611004
# Validation loss: 5.793087005615234 RMSE: 2.4068832
# 196 14 1.446786642074585
# Validation loss: 6.3795245885849 RMSE: 2.5257719
# Validation loss: 5.9811413288116455 RMSE: 2.4456375
# Validation loss: 6.682047367095947 RMSE: 2.584966
# Validation loss: 9.189380645751953 RMSE: 3.031399
# Loaded trained model with success.
# Test loss: 7.988293926990949 Test RMSE: 2.826357
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# {'batch_size': 32, 'epochs': 200, 'eval_every_n_epochs': 1, 'fine_tune_from': 'pretrained_gin', 'log_every_n_steps': 50, 'fp16_precision': False, 'init_lr': 0.0005, 'init_base_lr': 0.0001, 'weight_decay': '1e-6', 'gpu': 'cuda:1', 'task_name': 'freesolv', 'model_type': 'gin', 'model': {'num_layer': 3, 'emb_dim': 64, 'feat_dim': 64, 'drop_ratio': 0.5, 'pool': 'mean'}, 'dataset': {'num_workers': 4, 'valid_size': 0.1, 'test_size': 0.1, 'splitting': 'scaffold', 'seed': 779, 'task': 'regression', 'data_path': 'data/freesolv/freesolv.csv', 'target': ['expt']}}
# Running on: cuda:1
# 641
# About to generate scaffolds
# Generating scaffold 0/641
# About to sort in scaffold sets
# pred_head.0.weight True
# pred_head.0.bias True
# pred_head.2.weight True
# pred_head.2.bias True
# pred_head.4.weight True
# pred_head.4.bias True
# 0 0 23.131467819213867
# Validation loss: 72.8760929107666 RMSE: 8.536749
# Validation loss: 67.86685371398926 RMSE: 8.238134
# Validation loss: 60.15986633300781 RMSE: 7.756279
# 3 2 29.894058227539062
# Validation loss: 47.760337829589844 RMSE: 6.9108853
# Validation loss: 23.134970664978027 RMSE: 4.8098826
# Validation loss: 8.899657726287842 RMSE: 2.9832294
# 6 4 5.463200569152832
# Validation loss: 6.877941608428955 RMSE: 2.622583
# Validation loss: 8.75987434387207 RMSE: 2.9597085
# Validation loss: 7.47733736038208 RMSE: 2.734472
# 9 6 5.698376655578613
# Validation loss: 7.103290319442749 RMSE: 2.6652
# Validation loss: 5.225592613220215 RMSE: 2.2859554
# Validation loss: 6.723448038101196 RMSE: 2.5929613
# 12 8 2.3026134967803955
# Validation loss: 4.795350551605225 RMSE: 2.1898289
# Validation loss: 5.285138130187988 RMSE: 2.2989428
# Validation loss: 5.314242839813232 RMSE: 2.305264
# 15 10 4.459924697875977
# Validation loss: 4.8872270584106445 RMSE: 2.2107074
# Validation loss: 5.674774169921875 RMSE: 2.3821785
# Validation loss: 5.287579774856567 RMSE: 2.2994738
# 18 12 7.546804904937744
# Validation loss: 5.739832401275635 RMSE: 2.3957946
# Validation loss: 6.1338112354278564 RMSE: 2.4766533
# Validation loss: 4.705782651901245 RMSE: 2.1692815
# 21 14 2.7633304595947266
# Validation loss: 4.55219829082489 RMSE: 2.133588
# 165 10 1.0715724229812622
# Validation loss: 4.306500434875488 RMSE: 2.075211
# Validation loss: 5.002654790878296 RMSE: 2.2366614
# Validation loss: 3.775441527366638 RMSE: 1.9430497
# 168 12 1.8211965560913086
# Validation loss: 3.4141008853912354 RMSE: 1.8477286
# Validation loss: 6.150780916213989 RMSE: 2.4800768
# Validation loss: 4.247915148735046 RMSE: 2.061047
# 171 14 1.1685885190963745
# Validation loss: 5.4566755294799805 RMSE: 2.3359528
# Validation loss: 3.6136882305145264 RMSE: 1.9009703
# Validation loss: 3.948631167411804 RMSE: 1.9871165
# Validation loss: 5.2450960874557495 RMSE: 2.2902174
# 175 0 0.7326134443283081
# Validation loss: 4.199235439300537 RMSE: 2.0492036
# Validation loss: 3.9476797580718994 RMSE: 1.986877
# Validation loss: 5.3063437938690186 RMSE: 2.3035502
# 178 2 1.6228306293487549
# Validation loss: 4.585088014602661 RMSE: 2.1412818
# Validation loss: 3.86075496673584 RMSE: 1.9648802
# Validation loss: 5.272878646850586 RMSE: 2.296275
# 181 4 1.1454707384109497
# Validation loss: 3.6401140689849854 RMSE: 1.9079082
# Validation loss: 4.053994417190552 RMSE: 2.0134535
# Validation loss: 4.8837268352508545 RMSE: 2.2099156
# 184 6 0.9533601999282837
# Validation loss: 4.4676268100738525 RMSE: 2.113676
# Validation loss: 4.79334282875061 RMSE: 2.1893704
# Validation loss: 3.1465152502059937 RMSE: 1.773842
# 187 8 0.5985110998153687
# Validation loss: 3.774937152862549 RMSE: 1.9429197
# Validation loss: 3.176780581474304 RMSE: 1.7823523
# Validation loss: 4.585334420204163 RMSE: 2.1413395
# 190 10 0.897642970085144
# Validation loss: 3.767889142036438 RMSE: 1.9411051
# Validation loss: 4.86597466468811 RMSE: 2.2058957
# Validation loss: 3.486133098602295 RMSE: 1.867119
# 193 12 0.6708740592002869
# Validation loss: 3.57731032371521 RMSE: 1.8913778
# Validation loss: 4.504637837409973 RMSE: 2.1224132
# Validation loss: 5.141618490219116 RMSE: 2.2675138
# 196 14 1.3034698963165283
# Validation loss: 4.885559320449829 RMSE: 2.21033
# Validation loss: 5.450177431106567 RMSE: 2.3345616
# Validation loss: 5.4609034061431885 RMSE: 2.3368576
# Validation loss: 4.334685325622559 RMSE: 2.0819905
# Loaded trained model with success.
# Test loss: 7.313481947091909 Test RMSE: 2.704345
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# {'batch_size': 32, 'epochs': 200, 'eval_every_n_epochs': 1, 'fine_tune_from': 'pretrained_gin', 'log_every_n_steps': 50, 'fp16_precision': False, 'init_lr': 0.0005, 'init_base_lr': 0.0001, 'weight_decay': '1e-6', 'gpu': 'cuda:1', 'task_name': 'freesolv', 'model_type': 'gin', 'model': {'num_layer': 3, 'emb_dim': 64, 'feat_dim': 64, 'drop_ratio': 0.5, 'pool': 'mean'}, 'dataset': {'num_workers': 4, 'valid_size': 0.1, 'test_size': 0.1, 'splitting': 'scaffold', 'seed': 780, 'task': 'regression', 'data_path': 'data/freesolv/freesolv.csv', 'target': ['expt']}}
# Running on: cuda:1
# 641
# About to generate scaffolds
# Generating scaffold 0/641
# About to sort in scaffold sets
# Validation loss: 10.216247081756592 RMSE: 3.1962864
# 143 12 1.7556357383728027
# Validation loss: 9.881769180297852 RMSE: 3.1435282
# Validation loss: 6.976665496826172 RMSE: 2.6413379
# Validation loss: 8.680454730987549 RMSE: 2.9462612
# 146 14 1.1729962825775146
# Validation loss: 7.227449655532837 RMSE: 2.6883917
# Validation loss: 9.239011287689209 RMSE: 3.0395744
# Validation loss: 8.85451889038086 RMSE: 2.9756544
# Validation loss: 9.27603816986084 RMSE: 3.0456588
# 150 0 1.8356289863586426
# Validation loss: 6.665543079376221 RMSE: 2.5817711
# Validation loss: 8.532164096832275 RMSE: 2.9209867
# Validation loss: 9.4284987449646 RMSE: 3.0705862
# 153 2 1.076683759689331
# ...
# 186 28 0.04219038411974907
# Validation loss: 0.3262847557470396 ROC AUC: 0.733556159527823
# 187 1 0.024832142516970634
# 187 51 0.06368967145681381
# Validation loss: 0.34782411874114694 ROC AUC: 0.7371776798679894
# 188 24 0.061459969729185104
# 188 74 0.01973082683980465
# Validation loss: 0.3442397969109671 ROC AUC: 0.7251725553129998
# 189 47 0.020565053448081017
# Validation loss: 0.3478208137797071 ROC AUC: 0.7350303559354169
# 190 20 0.018419427797198296
# 190 70 0.03465188667178154
# Validation loss: 0.3700647139317029 ROC AUC: 0.7266191785271149
# 191 43 0.0371818020939827
# Validation loss: 0.3503683422292982 ROC AUC: 0.7405407977370798
# 192 16 0.03115317039191723
# 192 66 0.025812694802880287
# Validation loss: 0.3589120561426336 ROC AUC: 0.7151835808762853
# 193 39 0.06026579812169075
# Validation loss: 0.3598891529556993 ROC AUC: 0.720573448186996
# 194 12 0.046588946133852005
# 194 62 0.0371696911752224
# Validation loss: 0.3198441806938741 ROC AUC: 0.7388801373973536
# 195 35 0.04074131324887276
# Validation loss: 0.34319756034906806 ROC AUC: 0.7385023048545728
# 196 8 0.05221352353692055
# 196 58 0.04947701096534729
# Validation loss: 0.3525064846911988 ROC AUC: 0.7240834367949169
# 197 31 0.04774951562285423
# Validation loss: 0.3488319907095525 ROC AUC: 0.7314108892402459
# 198 4 0.07617153972387314
# 198 54 0.078330397605896
# Validation loss: 0.3586664010177959 ROC AUC: 0.7257675151839286
# 199 27 0.06234848499298096
# Validation loss: 0.3416281021260596 ROC AUC: 0.7234135717064528
# Loaded trained model with success.
# Test loss: 0.15534603789255216 Test ROC AUC: 0.7030359178146561
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# {'batch_size': 32, 'epochs': 200, 'eval_every_n_epochs': 1, 'fine_tune_from': 'pretrained_gin', 'log_every_n_steps': 50, 'fp16_precision': False, 'init_lr': 0.0005, 'init_base_lr': 0.0001, 'weight_decay': '1e-6', 'gpu': 'cuda:1', 'task_name': 'tox21', 'model_type': 'gin', 'model': {'num_layer': 5, 'emb_dim': 300, 'feat_dim': 300, 'drop_ratio': 0.3, 'pool': 'mean'}, 'dataset': {'num_workers': 4, 'valid_size': 0.1, 'test_size': 0.1, 'splitting': 'scaffold', 'seed': 780, 'task': 'classification', 'data_path': 'data/tox21/tox21.csv', 'target': ['NR-AR', 'NR-AR-LBD', 'NR-AhR', 'NR-Aromatase', 'NR-ER', 'NR-ER-LBD', 'NR-PPAR-gamma', 'SR-ARE', 'SR-ATAD5', 'SR-HSE', 'SR-MMP', 'SR-p53']}}
# 105 15 0.10223335027694702
# 105 65 0.027936488389968872
# Validation loss: 0.2530152050705699 ROC AUC: 0.7427171894982939
# 106 38 0.09506428241729736
# Validation loss: 0.26026196719764116 ROC AUC: 0.7412508308370439
# 107 11 0.06658110022544861
# 107 61 0.05764758959412575
# Validation loss: 0.2445821479543463 ROC AUC: 0.7589752447970671
# 108 34 0.03249233588576317
# Validation loss: 0.24946360657741498 ROC AUC: 0.7152973869718354
# 109 7 0.060620296746492386
# 109 57 0.05824107304215431
# Validation loss: 0.2404097868250562 ROC AUC: 0.7540693818578276
# 110 30 0.0522221177816391
# Validation loss: 0.2658440687439658 ROC AUC: 0.7323199863715754
# 111 3 0.08360563963651657
# 111 53 0.06735377758741379
# Validation loss: 0.23659749116216386 ROC AUC: 0.7483146211044773
# 112 26 0.07404536753892899
# 112 76 0.05888724699616432
# Validation loss: 0.2288971036285549 ROC AUC: 0.7578646288080749
# 113 49 0.030328625813126564
# Validation loss: 0.2442048949661193 ROC AUC: 0.7321389922950763
# 114 22 0.07852267473936081
# 114 72 0.06581716239452362
# Validation loss: 0.23553040352734653 ROC AUC: 0.7585474874267998
# 115 45 0.039553526788949966
# Validation loss: 0.24528465990896348 ROC AUC: 0.7490614702516653
# 116 18 0.035907577723264694
# 116 68 0.04091901704668999
# Validation loss: 0.23289120893973808 ROC AUC: 0.7425309639318852
# 117 41 0.04139168560504913
# Validation loss: 0.24747033920380976 ROC AUC: 0.7358907033777551
# 118 14 0.046652764081954956
# 118 64 0.04047718271613121
# Validation loss: 0.2692821250333414 ROC AUC: 0.7102700497214354
# 119 37 0.1328684389591217
# Validation loss: 0.2571366202908677 ROC AUC: 0.738693395611839
# 120 10 0.03642125427722931
# 120 60 0.03902529180049896
# Validation loss: 0.2543672899921219 ROC AUC: 0.7562437540053967
# 121 33 0.03420265391469002
# Validation loss: 0.2506935503575709 ROC AUC: 0.7666026546447431
# 122 6 0.05457405745983124
# 122 56 0.054464954882860184
# Validation loss: 0.24045675799444124 ROC AUC: 0.7606429284118753
# 123 29 0.10162059217691422
# Validation loss: 0.22793591099900085 ROC AUC: 0.7547713626020474
# 124 2 0.048540662974119186
# 124 52 0.057708460837602615
# Validation loss: 0.23624904744036787 ROC AUC: 0.7618417974057352
# 125 25 0.06750065088272095
# 125 75 0.03674422204494476
# Validation loss: 0.28995981696364165 ROC AUC: 0.7014557928156563
# 126 48 0.036237698048353195
# Validation loss: 0.26130705104245766 ROC AUC: 0.7414520509211219
# 127 21 0.04423736035823822

# %%
seeds = list(range(777,782))
# datasets = ["bace",  "bbbp", "tox21", "toxcast", "sider",  ]
datasets = [ 'tox21', 'clintox', 'sider', ]


for dataset in datasets:
    for seed in seeds: 
        # !python finetuneRecon.py \
        --task_name {dataset} \
        --splitting scaffold \
        --seed {seed} \
        --alpha 0.1

# %%
seeds = list(range(777,782))
# datasets = ["bace",  "bbbp", "tox21", "toxcast", "sider",  ]
datasets = [ 'tox21', 'clintox', 'sider', ]
for dataset in datasets:
    for seed in seeds: 
        # !python finetune3.py \
        --task_name {dataset} \
        --splitting scaffold \
        --seed {seed} \

# %%
seeds = list(range(777,782))
# datasets = ["bace",  "bbbp", "tox21", "toxcast", "sider",  ]
datasets = ["freeSolv",  "lipo", "esol", "qm7", "bace",  "bbbp", ]

for dataset in datasets:
    for seed in seeds: 
        # !python finetuneRecon.py \
        --task_name {dataset} \
        --splitting scaffold \
        --seed {seed} \
        --alpha 0.1

# %%
for seed in seeds:
    # !python finetuneReconFrag.py \
    --task_name freeSolv \
    --splitting scaffold \
    --seed 752
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for seed in seeds:
#       2     get_ipython().system('python finetuneReconFrag.py      --task_name freeSolv      --splitting scaffold      --seed 752')
#
# NameError: name 'seeds' is not defined

# %%
# !python finetuneReconRich_frag.py \
--task_name bbbp \
--seed 750 \
--alpha 0.1 \
--mask_edge 1 \
--gpu cuda:1
# Out:
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# {'batch_size': 32, 'epochs': 200, 'eval_every_n_epochs': 1, 'fine_tune_from': 'pretrained_gin', 'log_every_n_steps': 50, 'fp16_precision': False, 'init_lr': 0.0005, 'init_base_lr': 0.0001, 'weight_decay': '1e-6', 'gpu': 'cuda:1', 'task_name': 'bbbp', 'model_type': 'gin', 'model': {'num_layer': 5, 'emb_dim': 300, 'feat_dim': 300, 'drop_ratio': 0.3, 'pool': 'mean'}, 'dataset': {'num_workers': 4, 'valid_size': 0.1, 'test_size': 0.1, 'splitting': 'scaffold', 'seed': 750, 'task': 'classification', 'data_path': 'data/bbbp/BBBP.csv', 'target': ['p_np']}}
# Running on: cuda:1
# 2038
# About to generate scaffolds
# Generating scaffold 0/2038
# Generating scaffold 1000/2038
# Generating scaffold 2000/2038
# About to sort in scaffold sets
# pred_head.0.weight True
# pred_head.0.bias True
# pred_head.2.weight True
# pred_head.2.bias True
# pred_head.4.weight True
# pred_head.4.bias True
# 0 0 1.355644702911377
# 0 50 0.619223952293396
# Validation loss: 0.7503363022617265 ROC AUC: 0.9070263975155278
# 1 49 0.5505529642105103
# Validation loss: 0.49966833462902144 ROC AUC: 0.907705745341615
# 2 48 0.3681749701499939
# Validation loss: 0.46270505470388074 ROC AUC: 0.8852872670807453
# ^C
# ERROR:root:Could not compute fr_pyridine for molecule
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/descriptastorus/descriptors/rdNormalizedDescriptors.py", line 62, in applyNormalizedFunc
#     return cdfs[name](rdDescriptors.applyFunc(name,m))
#   File "/opt/conda/lib/python3.10/site-packages/descriptastorus/descriptors/rdNormalizedDescriptors.py", line 49, in cdf
#     v = dist.cdf(np.clip(v, minV, maxV), loc=loc, scale=scale, *arg)
#   File "<__array_function__ internals>", line 200, in clip
#   File "/opt/conda/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 2180, in clip
#     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 54, in _wrapfunc
#     return _wrapit(obj, method, *args, **kwds)
#   File "/opt/conda/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 43, in _wrapit
#     result = getattr(asarray(obj), method)(*args, **kwds)
#   File "/opt/conda/lib/python3.10/site-packages/numpy/core/_methods.py", line 127, in _clip
#     def _clip(a, min=None, max=None, out=None, *, casting=None, **kwargs):
# KeyboardInterrupt
# ERROR:root:Could not compute Kappa2 for molecule
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/descriptastorus/descriptors/rdNormalizedDescriptors.py", line 62, in applyNormalizedFunc
#     return cdfs[name](rdDescriptors.applyFunc(name,m))
#   File "/opt/conda/lib/python3.10/site-packages/descriptastorus/descriptors/rdNormalizedDescriptors.py", line 49, in cdf
#     v = dist.cdf(np.clip(v, minV, maxV), loc=loc, scale=scale, *arg)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py", line 1986, in cdf
#     dtyp = np.find_common_type([x.dtype, np.float64], [])
#   File "/opt/conda/lib/python3.10/site-packages/numpy/core/numerictypes.py", line 652, in find_common_type
#     maxa = _can_coerce_all(array_types)
#   File "/opt/conda/lib/python3.10/site-packages/numpy/core/numerictypes.py", line 583, in _can_coerce_all
#     if numcoerce == N:
# KeyboardInterrupt
# ERROR:root:Could not compute fr_piperzine for molecule
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/descriptastorus/descriptors/rdNormalizedDescriptors.py", line 62, in applyNormalizedFunc
#     return cdfs[name](rdDescriptors.applyFunc(name,m))
#   File "/opt/conda/lib/python3.10/site-packages/descriptastorus/descriptors/rdNormalizedDescriptors.py", line 49, in cdf
#     v = dist.cdf(np.clip(v, minV, maxV), loc=loc, scale=scale, *arg)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py", line 1996, in cdf
#     goodargs = argsreduce(cond, *((x,)+args))
#   File "/opt/conda/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py", line 572, in argsreduce
#     *newargs, cond = np.broadcast_arrays(*newargs, cond)
#   File "<__array_function__ internals>", line 200, in broadcast_arrays
#   File "/opt/conda/lib/python3.10/site-packages/numpy/lib/stride_tricks.py", line 540, in broadcast_arrays
#     shape = _broadcast_shape(*args)
# KeyboardInterrupt
# ERROR:root:Could not compute LabuteASA for molecule
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/descriptastorus/descriptors/rdNormalizedDescriptors.py", line 62, in applyNormalizedFunc
#     return cdfs[name](rdDescriptors.applyFunc(name,m))
#   File "/opt/conda/lib/python3.10/site-packages/descriptastorus/descriptors/rdNormalizedDescriptors.py", line 49, in cdf
#     v = dist.cdf(np.clip(v, minV, maxV), loc=loc, scale=scale, *arg)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py", line 1995, in cdf
#     if np.any(cond):  # call only if at least 1 entry
#   File "<__array_function__ internals>", line 200, in any
#   File "/opt/conda/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 2423, in any
#     return _wrapreduction(a, np.logical_or, 'any', axis, None, out,
#   File "/opt/conda/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 84, in _wrapreduction
#     return reduction(axis=axis, out=out, **passkwargs)
#   File "/opt/conda/lib/python3.10/site-packages/numpy/core/_methods.py", line 58, in _any
#     return umr_any(a, axis, dtype, out, keepdims)
# KeyboardInterrupt

# %%
import torch
import torch.nn as nn

# 0과 1로 구성된 범주형 변수의 임베딩 설정
num_categories = 2  # 범주의 개수 (0과 1)
emb_dim = 10  # 임베딩 차원

# nn.Embedding 레이어 생성
embedding_layer = nn.Embedding(num_embeddings=num_categories, embedding_dim=emb_dim)

# 범주형 변수의 인덱스를 나타내는 텐서 생성
# 예를 들어, [1, 0, 1, 1, 0]와 같은 텐서를 가정합니다.
category_indices = torch.tensor([1, 0, 1, 1, 0])

# 범주형 변수의 인덱스를 임베딩 레이어에 전달하여 임베딩 벡터를 조회
embedded = embedding_layer(category_indices)

print("Category indices:", category_indices)
print("Embedded vectors:\n", embedded)
# Out:
# Category indices: tensor([1, 0, 1, 1, 0])
# Embedded vectors:
#  tensor([[-1.1825, -0.9537,  1.0269,  1.1472,  0.4052, -1.2119,  1.9069, -1.1420,
#          -1.9693,  1.1902],
#         [-0.6348, -0.2631,  0.6851, -0.1353, -0.8161,  1.4514, -2.0473,  0.1509,
#          -1.0221, -1.5114],
#         [-1.1825, -0.9537,  1.0269,  1.1472,  0.4052, -1.2119,  1.9069, -1.1420,
#          -1.9693,  1.1902],
#         [-1.1825, -0.9537,  1.0269,  1.1472,  0.4052, -1.2119,  1.9069, -1.1420,
#          -1.9693,  1.1902],
#         [-0.6348, -0.2631,  0.6851, -0.1353, -0.8161,  1.4514, -2.0473,  0.1509,
#          -1.0221, -1.5114]], grad_fn=<EmbeddingBackward0>)

# %%
embedded.shape
# Out:
# torch.Size([5, 10])

# %%
# 임베딩 설정: 총 10개의 범주형 태그와 각 태그에 대한 5차원 임베딩 벡터
num_chirality_tags = 10  # 범주형 태그의 개수 (예: 0~9까지의 태그)
emb_dim = 5  # 임베딩 차원

# nn.Embedding 인스턴스 생성
embedding = nn.Embedding(num_chirality_tags, emb_dim)

# 다차원 입력 텐서 생성
# 예를 들어, 2x3 크기의 텐서로, 각 요소는 특정 범주형 태그의 인덱스
input_tensor = torch.tensor([[1, 2, 3], [4, 5, 6]])

# 임베딩 적용
embedded_tensor = embedding(input_tensor)

embedded_tensor.shape, embedded_tensor
# Out:
# (torch.Size([2, 3, 5]),
#  tensor([[[-0.8384, -0.6729,  0.2846,  0.4423, -1.3507],
#           [ 1.1084, -1.5312,  0.2718, -0.4837,  1.8607],
#           [ 0.3326, -0.1193, -0.8705, -0.6009, -0.4164]],
#
#          [[-1.0632,  1.0288,  0.5488, -1.7929,  0.3330],
#           [ 1.5004, -0.4843, -0.9040,  0.6776, -1.0243],
#           [ 3.4435, -0.6644,  0.6785, -1.0914,  1.7393]]],
#         grad_fn=<EmbeddingBackward0>))

# %%
input_tensor.shape
# Out:
# torch.Size([2, 3])

# %%
import torch
from torch_geometric.data import Data

# 노드 특성의 차원 (임의로 설정)
node_feature_dim = 64
num_nodes = 8  # 노드의 수 (임의로 설정)
num_edges = 12  # 엣지의 수 (임의로 설정)
edge_feature_dim = 10

# 노드 특성 생성 (노드 수 x 노드 특성 차원)
node_features = torch.randn(num_nodes, node_feature_dim)

# 엣지 인덱스 생성 (2 x 엣지 수) - 각 엣지는 (시작 노드, 종료 노드) 쌍으로 표현
# 예를 들어, 0번 노드에서 1번 노드로의 엣지, 1번 노드에서 2번 노드로의 엣지 등
edge_index = torch.randint(0, num_nodes, (2, num_edges), dtype=torch.long)

# 엣지 특성 생성 (엣지 수 x 엣지 특성 차원)
edge_features = torch.randn(num_edges, edge_feature_dim)

# 데이터 객체 생성
data = Data(x=node_features, edge_index=edge_index, edge_attr=edge_features)

data
# Out:
# Data(x=[8, 64], edge_index=[2, 12], edge_attr=[12, 10])

# %%
from typing import Callable, Optional, Union

import torch
from torch import Tensor

from torch_geometric.nn.conv import MessagePassing
from torch_geometric.nn.dense.linear import Linear
from torch_geometric.nn.inits import reset
from torch_geometric.typing import (
    Adj,
    OptPairTensor,
    OptTensor,
    Size,
    SparseTensor,
)
from torch_geometric.utils import spmm

# %%
class GINEConv(MessagePassing):

    def __init__(self, nn: torch.nn.Module, eps: float = 0.,
                 train_eps: bool = False, edge_dim: Optional[int] = None,
                 **kwargs):
        kwargs.setdefault('aggr', 'add')
        super().__init__(**kwargs)
        self.nn = nn
        self.initial_eps = eps
        if train_eps:
            self.eps = torch.nn.Parameter(torch.empty(1))
        else:
            self.register_buffer('eps', torch.empty(1))
        if edge_dim is not None:
            if isinstance(self.nn, torch.nn.Sequential):
                nn = self.nn[0]
            if hasattr(nn, 'in_features'):
                in_channels = nn.in_features
            elif hasattr(nn, 'in_channels'):
                in_channels = nn.in_channels
            else:
                raise ValueError("Could not infer input channels from `nn`.")

            self.lin = Linear(edge_dim, 64)

        else:
            self.lin = None
        self.reset_parameters()

    def reset_parameters(self):
        reset(self.nn)
        self.eps.data.fill_(self.initial_eps)
        if self.lin is not None:
            self.lin.reset_parameters()

    def forward(
        self,
        x: Union[Tensor, OptPairTensor],
        edge_index: Adj,
        edge_attr: OptTensor = None,
        size: Size = None,
    ) -> Tensor:

        if isinstance(x, Tensor):
            x = (x, x)

        # propagate_type: (x: OptPairTensor, edge_attr: OptTensor)
        out = self.propagate(edge_index, x=x, edge_attr=edge_attr, size=size)

        x_r = x[1]
        if x_r is not None:
            out = out + (1 + self.eps) * x_r

        return self.nn(out)

    def message(self, x_j: Tensor, edge_attr: Tensor) -> Tensor:
        if self.lin is None and x_j.size(-1) != edge_attr.size(-1):
            raise ValueError("Node and edge feature dimensionalities do not "
                             "match. Consider setting the 'edge_dim' "
                             "attribute of 'GINEConv'")

        if self.lin is not None:
            edge_attr = self.lin(edge_attr)

        print(x_j.shape, edge_attr.shape)

        return (x_j + edge_attr).relu()

    def __repr__(self) -> str:
        return f'{self.__class__.__name__}(nn={self.nn})'

# %%
import torch
from torch.nn import Sequential, Linear, ReLU

# GINEConv 레이어의 내부 MLP 정의
# 엣지 특성의 차원
edge_feature_dim = 10
node_feature_dim = 64  # 노드 특성 차원과 일치해야 함
emb_dim  = 128

# 수정된 GINEConv 레이어의 내부 MLP 정의
nn = Sequential(Linear(node_feature_dim, 32), ReLU(), Linear(32, 64))  # 출력 차원을 64로 설정

# GINEConv 레이어 초기화
conv = GINEConv(nn, edge_dim=edge_feature_dim)

# GINEConv 레이어 초기화

# 노드 특성, 엣지 인덱스, 엣지 특성 정의 (위에서 생성한 Data 객체 사용)
num_nodes = 5
node_feature_dim = 64
num_edges = 4

x = torch.randn((num_nodes, node_feature_dim))  # 노드 특성


edge_index = torch.randint(0, num_nodes, (2, num_edges))  # 엣지 인덱스
edge_attr = torch.randn((num_edges, edge_feature_dim))  # 엣지 특성

# %%
ㅇㅇ
