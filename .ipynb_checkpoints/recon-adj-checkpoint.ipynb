# %%
datasets = [ 'tox21', 'clintox', 'sider', ]
seeds = [777, 778, 779, 780, 781]

for dataset in datasets:
    for seed in seeds:
            # !python finetuneReconTop.py \
            --task_name {dataset} \
            --seed {seed} \
            --alpha 0.1 \
            --random_masking 1
# Out:
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# {'batch_size': 32, 'epochs': 200, 'eval_every_n_epochs': 1, 'fine_tune_from': 'pretrained_gin', 'log_every_n_steps': 50, 'fp16_precision': False, 'init_lr': 0.0005, 'init_base_lr': 0.0001, 'weight_decay': '1e-6', 'gpu': 'cuda:0', 'task_name': 'tox21', 'model_type': 'gin', 'model': {'num_layer': 5, 'emb_dim': 300, 'feat_dim': 300, 'drop_ratio': 0.3, 'pool': 'mean'}, 'dataset': {'num_workers': 4, 'valid_size': 0.1, 'test_size': 0.1, 'splitting': 'scaffold', 'seed': 777, 'task': 'classification', 'data_path': 'data/tox21/tox21.csv', 'target': ['NR-AR', 'NR-AR-LBD', 'NR-AhR', 'NR-Aromatase', 'NR-ER', 'NR-ER-LBD', 'NR-PPAR-gamma', 'SR-ARE', 'SR-ATAD5', 'SR-HSE', 'SR-MMP', 'SR-p53']}}
# Running on: cuda:0
# 3079
# About to generate scaffolds
# Generating scaffold 0/3079
# Generating scaffold 1000/3079
# Generating scaffold 2000/3079
# Generating scaffold 3000/3079
# About to sort in scaffold sets
# pred_head.0.weight True
# pred_head.0.bias True
# pred_head.2.weight True
# pred_head.2.bias True
# pred_head.4.weight True
# pred_head.4.bias True
# 0 0 1.2206017971038818
# 0 50 0.1804627776145935
# Validation loss: 0.17493074861439792 ROC AUC: 0.7414903988425311
# 1 23 0.1765616238117218
# 1 73 0.09889876842498779
# Validation loss: 0.17725925805506768 ROC AUC: 0.7468405776138071
# 2 46 0.12018123269081116
# Validation loss: 0.16978831511813325 ROC AUC: 0.7549969179542098
# 3 19 0.07874653488397598
# 3 69 0.09496995061635971
# Validation loss: 0.17326760350109696 ROC AUC: 0.7453608162459627
# 4 42 0.10734247416257858
# Validation loss: 0.17139840609841533 ROC AUC: 0.7353942367734135
# 5 15 0.08433131873607635
# 5 65 0.10842856764793396
# Validation loss: 0.19067217487019378 ROC AUC: 0.6576255074103815
# 6 38 0.06701882183551788
# Validation loss: 0.17285244399076932 ROC AUC: 0.7439335003995006
# 7 11 0.14477896690368652
# 7 61 0.09307379275560379
# Validation loss: 0.17531693775158425 ROC AUC: 0.7150831341582159
# 8 34 0.13325423002243042
# Validation loss: 0.18377595481934486 ROC AUC: 0.6612426349598252
# 9 7 0.13892562687397003
# 9 57 0.07452276349067688
# Validation loss: 0.16380221377332488 ROC AUC: 0.7596631395354682
# 10 30 0.06156834959983826
# Validation loss: 0.1960420449832817 ROC AUC: 0.7236707112041469
# 11 3 0.09552664309740067
# 11 53 0.10027167946100235
# Validation loss: 0.1926297057758678 ROC AUC: 0.7263981914060659
# 12 26 0.09498757123947144
# 12 76 0.09664155542850494
# Validation loss: 0.16957076358330714 ROC AUC: 0.7394129936309293
# 13 49 0.10946101695299149
# Validation loss: 0.19993747751434127 ROC AUC: 0.5830768320073431
# 14 22 0.09777923673391342
# 14 72 0.09768952429294586
# 98 4 0.06284034252166748
# 98 54 0.09550386667251587
# Validation loss: 0.286433782670405 ROC AUC: 0.6509325007471002
# 99 27 0.025002852082252502
# Validation loss: 0.2732744375606636 ROC AUC: 0.6608762064403377
# 100 0 0.05017000809311867
# 100 50 0.08802376687526703
# Validation loss: 0.23725411392651596 ROC AUC: 0.6878153107336074
# 101 23 0.08521318435668945
# 101 73 0.06537819653749466
# Validation loss: 0.23862930048595776 ROC AUC: 0.6906947148903063
# 102 46 0.04279104992747307
# Validation loss: 0.3626270257420354 ROC AUC: 0.6203613661521542
# 103 19 0.04872499033808708
# 103 69 0.10700749605894089
# Validation loss: 0.33048076637379536 ROC AUC: 0.6374925172670983
# 104 42 0.05154457315802574
# Validation loss: 0.22189142622730948 ROC AUC: 0.7126405246603599
# 105 15 0.08094055205583572
# 105 65 0.08065202832221985
# Validation loss: 0.2595898311633568 ROC AUC: 0.691714898826194
# 106 38 0.08715447038412094
# Validation loss: 0.2707515989805197 ROC AUC: 0.6772962776704518
# 107 11 0.04107866808772087
# 107 61 0.057661112397909164
# Validation loss: 0.2320294976234436 ROC AUC: 0.7190215179868825
# 108 34 0.03957393392920494
# Validation loss: 0.2623195437254844 ROC AUC: 0.6858732386791266
# 109 7 0.07244856655597687
# 109 57 0.055143460631370544
# Validation loss: 0.2784200713231966 ROC AUC: 0.6966640343750309
# 110 30 0.0632452517747879
# Validation loss: 0.31202832831964866 ROC AUC: 0.6697248789331615
# 111 3 0.0497748889029026
# 111 53 0.06178136169910431
# Validation loss: 0.3228806040503762 ROC AUC: 0.6703178986117561
# 112 26 0.041204143315553665
# 112 76 0.0369543582201004
# Validation loss: 0.25736953724514355 ROC AUC: 0.6874423799738839
# 113 49 0.05434654280543327
# Validation loss: 0.28967139473209136 ROC AUC: 0.6445942813725468

# %%
seeds = list(range(777,782))
# datasets = ["bace",  "bbbp", "tox21", "toxcast", "sider",  ]
datasets = [ 'tox21', 'clintox', 'sider', ]


for dataset in datasets:
    for seed in seeds: 
        # !python finetuneRecon.py \
        --task_name {dataset} \
        --splitting scaffold \
        --seed {seed} \
        --alpha 0.1

# %%
seeds = list(range(777,782))
# datasets = ["bace",  "bbbp", "tox21", "toxcast", "sider",  ]
datasets = [ 'tox21', 'clintox', 'sider', ]
for dataset in datasets:
    for seed in seeds: 
        # !python finetune3.py \
        --task_name {dataset} \
        --splitting scaffold \
        --seed {seed} \

# %%
seeds = list(range(777,782))
# datasets = ["bace",  "bbbp", "tox21", "toxcast", "sider",  ]
datasets = ["freeSolv",  "lipo", "esol", "qm7", "bace",  "bbbp", ]

for dataset in datasets:
    for seed in seeds: 
        # !python finetuneRecon.py \
        --task_name {dataset} \
        --splitting scaffold \
        --seed {seed} \
        --alpha 0.1

# %%
seeds = [range(777,782)]
for seed in seeds:
    # !python finetuneRecon.py \
    --task_name freeSolv \
    --splitting scaffold \
    --seed {seed}

# %%
# !python finetuneReconTop.py \
--task_name freeSolv \
--seed 740 \
--dropout 0.5 \
--num_layer 3 \
--emb_dim 64 \
--feat_dim 64 \
--alpha 0.1 \
--random_masking 1
