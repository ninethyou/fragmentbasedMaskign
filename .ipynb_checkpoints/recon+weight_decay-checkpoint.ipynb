# %%
for seed in [777,778,779,780,781]
    # !python finetuneRecon-balanced.py \
    --task_name {dataset} \
    --seed {seed} \
    --gpu cuda:1 \
    --split balanced_scaffold

# %%
    # !python finetuneRecon-balanced.py \
    --task_name bbbp \
    --seed 350 \
    --gpu cuda:1 \
    --split balanced_scaffold \
    --weight_decay 1e-5
# Out:
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# {'batch_size': 32, 'epochs': 200, 'eval_every_n_epochs': 1, 'fine_tune_from': 'pretrained_gin', 'log_every_n_steps': 50, 'fp16_precision': False, 'init_lr': 0.0005, 'init_base_lr': 0.0001, 'weight_decay': '1e-5', 'gpu': 'cuda:1', 'task_name': 'bbbp', 'model_type': 'gin', 'model': {'num_layer': 5, 'emb_dim': 300, 'feat_dim': 300, 'drop_ratio': 0.3, 'pool': 'mean'}, 'dataset': {'num_workers': 4, 'valid_size': 0.1, 'test_size': 0.1, 'splitting': 'balanced_scaffold', 'seed': 350, 'task': 'classification', 'data_path': 'data/bbbp/BBBP.csv', 'target': ['p_np']}}
# Running on: cuda:1
# 100%|#####################################| 2038/2038 [00:00<00:00, 3871.94it/s]
# pred_head.0.weight True
# pred_head.0.bias True
# pred_head.2.weight True
# pred_head.2.bias True
# pred_head.4.weight True
# pred_head.4.bias True
# 0 0 5.8948493003845215
# 0 50 1.099350094795227
# ...

# %%
for seed in [777,778,779,780,781]:
    # !python finetuneRecon-balanced.py \
    --task_name freesolv \
    --seed {seed} \
    --gpu cuda:0 \
    --dropout 0.5 \
    --num_layer 2 \
    --emb_dim 64 \
    --feat_dim 64 \
    --split balanced_scaffold \
    --weight_decay 1e-2
# Out:
# Please install apex for mixed precision training from: https://github.com/NVIDIA/apex
# {'batch_size': 32, 'epochs': 200, 'eval_every_n_epochs': 1, 'fine_tune_from': 'pretrained_gin', 'log_every_n_steps': 50, 'fp16_precision': False, 'init_lr': 0.0005, 'init_base_lr': 0.0001, 'weight_decay': '1e-2', 'gpu': 'cuda:0', 'task_name': 'freesolv', 'model_type': 'gin', 'model': {'num_layer': 2, 'emb_dim': 64, 'feat_dim': 64, 'drop_ratio': 0.5, 'pool': 'mean'}, 'dataset': {'num_workers': 4, 'valid_size': 0.1, 'test_size': 0.1, 'splitting': 'balanced_scaffold', 'seed': 777, 'task': 'regression', 'data_path': 'data/freesolv/freesolv.csv', 'target': ['expt']}}
# Running on: cuda:0
# 100%|######################################| 641/641 [00:00<00:00, 12382.21it/s]
# pred_head.0.weight True
# pred_head.0.bias True
# pred_head.2.weight True
# pred_head.2.bias True
# pred_head.4.weight True
# pred_head.4.bias True
# 0 0 34.42776870727539
# Validation loss: 41.596153259277344 RMSE: 6.449508
# ...
