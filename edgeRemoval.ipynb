# %%
import os
import subprocess
from concurrent.futures import ThreadPoolExecutor
# 데이터셋, 시드, 알파 값, 그리고 GPU 장치 번호 설정
datasets = ['freesolv','esol','lipo','qm7','qm8', 'bbbp', 'bace', 'sider', 'toxcast', 'tox21', 'clintox', 'hiv']
seeds = [777, 778, 789]
devices = [0, 1]  # 사용 가능한 GPU 장치 번호

# 실행할 스크립트
script = 'pretrain2+finetune-edgeRemoval.py'

def run_script(script, dataset, seed, device):
    # pretrained model location
    input_model_directory = f"./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/"

    input_model_file = os.path.join(input_model_directory, 'model.pth')

    # 기본 커맨드 설정
    command = [
        'python', script,
        '--dataset', dataset,
        '--device', str(device),
        '--seed', str(seed),
        '--input_model_file', input_model_file
    ]

    # 현재 디렉토리 변경
    os.chdir('/tf/GraphMAE-pyg - copy/chem')

    # subprocess를 사용하여 명령어 실행실행
    subprocess.run(command, check=True)


# ThreadPoolExecutor로 병렬 실행
with ThreadPoolExecutor(max_workers=20) as executor:
    futures = []
    for i, (dataset, seed ) in enumerate([(d, s) for d in datasets for s in seeds ]):
        device = devices[i % len(devices)]  # GPU 장치 번호 순환
        # 각 조합에 대해 스크립트 실행을 스케줄
        future = executor.submit(run_script, script, dataset,seed, device)
        futures.append(future)
    
    # 결과 대기
    for future in futures:
        future.result()  # 실행 결과 확인
# Out:
# [02:48:02] WARNING: not removing hydrogen atom without neighbors
# [02:48:02] WARNING: not removing hydrogen atom without neighbors
# [02:48:02] WARNING: not removing hydrogen atom without neighbors
# [02:48:02] WARNING: not removing hydrogen atom without neighbors
# [02:48:02] WARNING: not removing hydrogen atom without neighbors
# [02:48:02] WARNING: not removing hydrogen atom without neighbors
# [02:48:02] WARNING: not removing hydrogen atom without neighbors
# MoleculeDataset(6834) qm7 777
# scaffold
# [02:48:03] WARNING: not removing hydrogen atom without neighbors
# [02:48:03] WARNING: not removing hydrogen atom without neighbors
# [02:48:03] WARNING: not removing hydrogen atom without neighbors
# [02:48:03] WARNING: not removing hydrogen atom without neighbors
# [02:48:03] WARNING: not removing hydrogen atom without neighbors
# [02:48:03] WARNING: not removing hydrogen atom without neighbors
# [02:48:03] WARNING: not removing hydrogen atom without neighbors
# MoleculeDataset(6834) qm7 789
# scaffold
# MoleculeDataset(642) freesolv 778
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s][02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s][02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# MoleculeDataset(642) freesolv 777
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:05] WARNING: not removing hydrogen atom without neighbors
# tensor(-1552.8820, dtype=torch.float64) tensor(228.9612, dtype=torch.float64) torch.Size([5440])
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# Iteration:   0%|          | 0/170 [00:00<?, ?it/s][02:48:05] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# Iteration:   6%|▋         | 1/16 [00:02<00:36,  2.42s/it][02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# Iteration:  38%|███▊      | 6/16 [00:02<00:03,  3.18it/s][02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# [02:48:06] WARNING: not removing hydrogen atom without neighbors
# Iteration:  81%|████████▏ | 13/16 [00:02<00:00,  8.08it/s]
# MoleculeDataset(6834) qm7 778
# scaffold
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 16/16 [00:02<00:00,  5.79it/s]
# Iteration:   0%|          | 0/28 [00:00<?, ?it/s]]
# tensor(-1552.8820, dtype=torch.float64) tensor(228.9612, dtype=torch.float64) torch.Size([5440])
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# MoleculeDataset(1128) esol 789
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# train_loss : inf val_loss: inf
# train: 0.000000 val: 6.406754  best_val_acc: 6.406754
# ====epoch 2
# MoleculeDataset(1128) esol 778
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# Iteration: 100%|██████████| 16/16 [00:00<00:00, 17.72it/s]]
# Iteration:  10%|█         | 17/170 [00:03<00:15,  9.58it/s]
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 16/16 [00:03<00:00,  4.03it/s]]
# Iteration:   0%|          | 0/50 [00:00<?, ?it/s]28.72it/s]
# MoleculeDataset(2039) bbbp 777
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# Iteration:  34%|███▍      | 58/170 [00:04<00:03, 33.02it/s]
# MoleculeDataset(1128) esol 777
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]31.35it/s]
# MoleculeDataset(2039) bbbp 789
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# train_loss : inf val_loss: inf
# train: 0.000000 val: 5.817737  best_val_acc: 5.817737
# ====epoch 3
# Iteration:  44%|████▍     | 7/16 [00:00<00:00, 13.41it/s]s]
# MoleculeDataset(4200) lipophilicity 778
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# train_loss : inf val_loss: inf
# train: 0.000000 val: 6.406762  best_val_acc: 6.406762
# ====epoch 2
# Iteration:  55%|█████▌    | 94/170 [00:05<00:02, 27.77it/s]
# MoleculeDataset(1513) bace 778
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# Iteration: 100%|██████████| 16/16 [00:01<00:00, 14.40it/s]]
# Iteration:  60%|██████    | 102/170 [00:06<00:02, 32.75it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 28/28 [00:05<00:00,  5.14it/s]]]
# Iteration:  72%|███████▏  | 122/170 [00:06<00:01, 26.96it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 16/16 [00:01<00:00, 10.98it/s]]]
# ====Evaluation
# omit the training accuracy computation
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s] 35.49it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 5.719180  best_val_acc: 5.719180
# ====epoch 4
# Iteration: 100%|██████████| 28/28 [00:05<00:00,  5.55it/s]s]
# Iteration:  38%|███▊      | 6/16 [00:00<00:00, 16.19it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:   0%|          | 0/28 [00:00<?, ?it/s] 35.58it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.978347  best_val_acc: 1.978347
# ====epoch 2
# ====Evaluation
# omit the training accuracy computation
# MoleculeDataset(2039) bbbp 778
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# Iteration: 100%|██████████| 170/170 [00:08<00:00, 20.79it/s]
# Iteration: 100%|██████████| 16/16 [00:00<00:00, 18.26it/s]s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s].63s/it]/s]
# MoleculeDataset(4200) lipophilicity 789
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# MoleculeDataset(642) freesolv 789
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# train_loss : inf val_loss: inf
# train: 0.000000 val: 5.817674  best_val_acc: 5.817674
# ====epoch 3
# Iteration:  88%|████████▊ | 14/16 [00:00<00:00, 25.38it/s]s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 2.008524  best_val_acc: 2.008524
# ====epoch 2
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 17.18it/s]s]
# Iteration:   2%|▏         | 1/50 [00:05<04:06,  5.03s/it]]s]
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 16/16 [00:01<00:00, 15.21it/s]
# Iteration: 100%|██████████| 28/28 [00:05<00:00,  5.14it/s]
# Iteration: 100%|██████████| 170/170 [00:08<00:00, 19.59it/s]
# Iteration:  12%|█▏        | 6/50 [00:05<00:22,  1.95it/s]]
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 50/50 [00:06<00:00,  7.80it/s]
# Iteration:  42%|████▏     | 21/50 [00:05<00:02, 11.32it/s]
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 107.075847  best_val_acc: 107.075847
# ====epoch 2
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]5.80it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 5.027781  best_val_acc: 5.027781
# ====epoch 5
# Iteration:  14%|█▍        | 15/105 [00:05<00:14,  6.24it/s]
# MoleculeDataset(1513) bace 777
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 17.88it/s]
# Iteration:  19%|█▉        | 3/16 [00:00<00:02,  5.38it/s]]]
# MoleculeDataset(4200) lipophilicity 777
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# Iteration: 100%|██████████| 50/50 [00:06<00:00,  7.35it/s]]
# Iteration:  35%|███▌      | 37/105 [00:06<00:02, 23.03it/s]
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 37/37 [00:06<00:00,  6.12it/s]]
# Iteration: 100%|██████████| 16/16 [00:01<00:00, 12.98it/s]]
# Iteration:  19%|█▉        | 33/170 [00:01<00:04, 29.32it/s]
# ====Evaluation
# omit the training accuracy computation
# tensor(-1552.8820, dtype=torch.float64) tensor(228.9612, dtype=torch.float64) torch.Size([5440])
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# Iteration:  60%|██████    | 63/105 [00:06<00:01, 30.39it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 5.707420  best_val_acc: 5.707420
# ====epoch 4
# Iteration:  26%|██▌       | 44/170 [00:01<00:04, 27.56it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.646631  best_val_acc: 1.646631
# ====epoch 3
# train_loss : inf val_loss: inf
# train: 0.000000 val: 5.306547  best_val_acc: 5.306547
# ====epoch 6
# Iteration: 100%|██████████| 16/16 [00:01<00:00, 14.36it/s]]
# Iteration:  21%|██        | 22/105 [00:04<00:07, 10.85it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 16/16 [00:01<00:00, 15.63it/s]s]
# Iteration: 100%|██████████| 16/16 [00:04<00:00,  3.24it/s]]]
# Iteration:  60%|██████    | 30/50 [00:05<00:01, 16.40it/s]
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 22.88it/s]]
# Iteration: 100%|██████████| 105/105 [00:08<00:00, 12.64it/s]
# Iteration:   0%|          | 0/28 [00:00<?, ?it/s]17.59it/s]
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 2.009023  best_val_acc: 2.009023
# ====epoch 2
# Iteration: 100%|██████████| 50/50 [00:06<00:00,  8.05it/s]s]
# Iteration:  21%|██▏       | 6/28 [00:00<00:01, 13.60it/s]
# ====Evaluation
# omit the training accuracy computation
# MoleculeDataset(21786) qm8 778
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 25.91it/s]s]
# Iteration:  32%|███▏      | 12/37 [00:04<00:04,  5.56it/s]]]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  84%|████████▍ | 88/105 [00:06<00:00, 34.44it/s]]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 119.397599  best_val_acc: 119.397599
# ====epoch 2
# Iteration:  91%|█████████▏| 96/105 [00:06<00:00, 34.14it/s]]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.855666  best_val_acc: 0.855666
# ====epoch 2
# Iteration: 100%|██████████| 170/170 [00:04<00:00, 34.04it/s]
# Iteration: 100%|██████████| 105/105 [00:07<00:00, 35.69it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 105/105 [00:07<00:00, 14.57it/s]
# Iteration:  21%|██        | 35/170 [00:03<00:05, 25.36it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 37/37 [00:05<00:00,  7.15it/s]]
# Iteration:  44%|████▍     | 22/50 [00:00<00:00, 36.40it/s]]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  64%|██████▍   | 32/50 [00:00<00:00, 41.81it/s]]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 116.117080  best_val_acc: 116.117080
# ====epoch 3
# Iteration:  86%|████████▌ | 43/50 [00:01<00:00, 47.62it/s]]
# MoleculeDataset(21786) qm8 777
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.650922  best_val_acc: 1.650922
# ====epoch 3
# Iteration: 100%|██████████| 50/50 [00:01<00:00, 34.64it/s]]
# MoleculeDataset(21786) qm8 789
# scaffold
# load pretrained model from: ./pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# ====epoch 1
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 105/105 [00:06<00:00, 16.33it/s]
# Iteration:  60%|██████    | 102/170 [00:05<00:01, 38.76it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 22.86it/s]]]
# Iteration:  66%|██████▋   | 113/170 [00:06<00:01, 42.96it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  73%|███████▎  | 124/170 [00:06<00:01, 43.61it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.847636  best_val_acc: 0.847636
# ====epoch 2
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.630037  best_val_acc: 0.630037
# ====epoch 2
# Iteration: 100%|██████████| 170/170 [00:03<00:00, 42.93it/s]
# Iteration: 100%|██████████| 170/170 [00:07<00:00, 23.80it/s]
# Iteration:  70%|███████   | 119/170 [00:02<00:01, 44.96it/s]
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 50/50 [00:01<00:00, 30.96it/s]]]
# Iteration: 100%|██████████| 37/37 [00:01<00:00, 24.06it/s]s]
# Iteration:  90%|█████████ | 153/170 [00:03<00:00, 51.44it/s]
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 170/170 [00:04<00:00, 42.42it/s]
# Iteration:  10%|█         | 56/544 [00:03<00:10, 45.91it/s]]
# ====Evaluation
# omit the training accuracy computation
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s] 66.71it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.499893  best_val_acc: 1.499893
# ====epoch 4
# train_loss : inf val_loss: inf
# train: 0.000000 val: 4.701644  best_val_acc: 4.701644
# ====epoch 7
# train_loss : inf val_loss: inf
# train: 0.000000 val: 5.019784  best_val_acc: 5.019784
# ====epoch 5
# Iteration: 100%|██████████| 16/16 [00:00<00:00, 23.64it/s]s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 6.406758  best_val_acc: 6.406758
# ====epoch 2
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.144097  best_val_acc: 1.144097
# ====epoch 2
# Iteration: 100%|██████████| 28/28 [00:00<00:00, 34.12it/s]
# Iteration: 100%|██████████| 16/16 [00:00<00:00, 23.09it/s]s]
# Iteration: 100%|██████████| 16/16 [00:00<00:00, 21.38it/s]s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.652842  best_val_acc: 1.652842
# ====epoch 5
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 5.282538  best_val_acc: 5.282538
# ====epoch 6
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.855666  best_val_acc: 0.855666
# ====epoch 2
# Iteration: 100%|██████████| 28/28 [00:00<00:00, 31.24it/s]s]
# Iteration:  43%|████▎     | 236/544 [00:06<00:06, 44.27it/s]
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.651390  best_val_acc: 1.651390
# ====epoch 3
# Iteration: 100%|██████████| 16/16 [00:00<00:00, 16.43it/s]s]
# Iteration:  45%|████▌     | 246/544 [00:07<00:06, 43.03it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  47%|████▋     | 257/544 [00:07<00:06, 46.43it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.718897  best_val_acc: 1.718897
# ====epoch 6
# Iteration: 100%|██████████| 50/50 [00:01<00:00, 31.44it/s]s]
# Iteration: 100%|██████████| 105/105 [00:02<00:00, 45.40it/s]
# Iteration:  56%|█████▌    | 305/544 [00:08<00:04, 54.40it/s]
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 27.65it/s]
# Iteration:  58%|█████▊    | 317/544 [00:08<00:04, 54.01it/s]
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.155804  best_val_acc: 1.155804
# ====epoch 2
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.627839  best_val_acc: 0.627839
# ====epoch 2
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 28/28 [00:00<00:00, 29.46it/s]s]
# Iteration:  16%|█▌        | 6/37 [00:00<00:02, 12.45it/s]s]]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.851840  best_val_acc: 1.851840
# ====epoch 7
# Iteration: 100%|██████████| 28/28 [00:00<00:00, 41.83it/s]s]
# Iteration:  97%|█████████▋| 529/544 [00:11<00:00, 71.23it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 544/544 [00:12<00:00, 45.22it/s]
# Iteration:  67%|██████▋   | 366/544 [00:09<00:04, 43.78it/s]
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.519024  best_val_acc: 1.519024
# ====epoch 8
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.886881  best_val_acc: 0.886881
# ====epoch 3
# Iteration: 100%|██████████| 37/37 [00:01<00:00, 20.11it/s]s]
# Iteration:  69%|██████▉   | 376/544 [00:10<00:03, 42.45it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 28/28 [00:00<00:00, 33.60it/s]]]
# Iteration:  78%|███████▊  | 424/544 [00:10<00:02, 43.20it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  78%|███████▊  | 39/50 [00:01<00:00, 50.14it/s]s]
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.506236  best_val_acc: 1.506236
# ====epoch 9
# Iteration: 100%|██████████| 105/105 [00:02<00:00, 38.07it/s]
# Iteration: 100%|██████████| 50/50 [00:01<00:00, 40.04it/s]s]
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.491885  best_val_acc: 1.491885
# ====epoch 4
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.159745  best_val_acc: 1.159745
# ====epoch 2
# Iteration: 100%|██████████| 28/28 [00:00<00:00, 37.89it/s]s]
# Iteration:  39%|███▉      | 11/28 [00:00<00:00, 23.37it/s]s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  86%|████████▌ | 469/544 [00:11<00:01, 48.13it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.884251  best_val_acc: 1.884251
# ====epoch 10
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 26.06it/s]s]
# Iteration:  90%|█████████ | 490/544 [00:12<00:01, 47.98it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 111.140812  best_val_acc: 111.140812
# ====epoch 3
# train_loss : inf val_loss: inf
# train: 0.000000 val: 109.819682  best_val_acc: 109.819682
# ====epoch 2
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.668132  best_val_acc: 0.668132
# ====epoch 3
# Iteration: 100%|██████████| 28/28 [00:00<00:00, 35.17it/s]]]
# Iteration:  60%|██████    | 63/105 [00:01<00:01, 40.86it/s]]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.754159  best_val_acc: 1.754159
# ====epoch 5
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.887684  best_val_acc: 0.887684
# ====epoch 3
# ====Evaluation
# omit the training accuracy computation
# Iteration:   0%|          | 0/170 [00:00<?, ?it/s]37.41it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 106.174869  best_val_acc: 106.174869
# ====epoch 4
# Iteration: 100%|██████████| 544/544 [00:13<00:00, 40.20it/s]
# Iteration:  83%|████████▎ | 87/105 [00:02<00:00, 37.97it/s]]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 544/544 [00:13<00:00, 39.61it/s]
# Iteration: 100%|██████████| 37/37 [00:01<00:00, 27.57it/s]
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 24.07it/s]]
# Iteration:  72%|███████▏  | 36/50 [00:01<00:00, 39.80it/s]]]
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 105/105 [00:03<00:00, 34.49it/s]
# Iteration:  39%|███▉      | 67/170 [00:01<00:02, 41.23it/s]
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 4.196118  best_val_acc: 4.196118
# ====epoch 8
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.623077  best_val_acc: 0.623077
# ====epoch 4
# Iteration: 100%|██████████| 50/50 [00:01<00:00, 30.19it/s]]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  31%|███       | 53/170 [00:01<00:02, 43.80it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.819219  best_val_acc: 1.819219
# ====epoch 6
# Iteration: 100%|██████████| 16/16 [00:00<00:00, 18.61it/s]s]
# Iteration:  59%|█████▉    | 22/37 [00:00<00:00, 32.98it/s]s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  89%|████████▉ | 33/37 [00:01<00:00, 39.06it/s]s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 5.817737  best_val_acc: 5.817737
# ====epoch 3
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 27.82it/s]s]
# Iteration: 100%|██████████| 37/37 [00:01<00:00, 28.44it/s]s]
# Iteration: 100%|██████████| 16/16 [00:00<00:00, 23.83it/s]s]
# Iteration:  93%|█████████▎| 158/170 [00:03<00:00, 50.01it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 4.688510  best_val_acc: 4.688510
# ====epoch 7
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.597802  best_val_acc: 0.597802
# ====epoch 5
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.789481  best_val_acc: 1.789481
# ====epoch 7
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 170/170 [00:04<00:00, 40.87it/s]
# Iteration: 100%|██████████| 170/170 [00:04<00:00, 39.74it/s]
# Iteration:  94%|█████████▎| 159/170 [00:03<00:00, 46.19it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.497497  best_val_acc: 1.497497
# ====epoch 4
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.886982  best_val_acc: 0.886982
# ====epoch 3
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 16/16 [00:00<00:00, 19.56it/s]s]
# Iteration:   0%|          | 0/105 [00:00<?, ?it/s]66it/s]
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.069366  best_val_acc: 1.069366
# ====epoch 3
# Iteration: 100%|██████████| 170/170 [00:03<00:00, 43.22it/s]
# Iteration:  82%|████████▏ | 23/28 [00:00<00:00, 31.32it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  86%|████████▋ | 32/37 [00:01<00:00, 32.87it/s]
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 112.954680  best_val_acc: 112.954680
# ====epoch 4
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 23.10it/s]
# Iteration: 100%|██████████| 37/37 [00:01<00:00, 25.81it/s]]
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 25.00it/s]]
# Iteration:   1%|          | 1/170 [00:00<00:59,  2.82it/s]]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  31%|███▏      | 33/105 [00:01<00:01, 44.98it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.526575  best_val_acc: 1.526575
# ====epoch 8
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.606593  best_val_acc: 0.606593
# ====epoch 6
# Iteration: 100%|██████████| 50/50 [00:01<00:00, 31.02it/s]]
# Iteration:  14%|█▎        | 5/37 [00:00<00:01, 16.59it/s]s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.705197  best_val_acc: 1.705197
# ====epoch 5
# ====Evaluation
# omit the training accuracy computation
# Iteration:  21%|██        | 35/170 [00:01<00:03, 43.59it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.030885  best_val_acc: 0.030885
# ====epoch 2
# Iteration: 100%|██████████| 28/28 [00:00<00:00, 31.21it/s]]
# Iteration:   2%|▏         | 12/544 [00:00<00:18, 29.52it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.671795  best_val_acc: 0.671795
# ====epoch 3
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.916993  best_val_acc: 0.916993
# ====epoch 4
# Iteration: 100%|██████████| 28/28 [00:00<00:00, 28.16it/s]]
# Iteration:   2%|▏         | 1/50 [00:00<00:16,  2.92it/s]s]
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.089350  best_val_acc: 1.089350
# ====epoch 3
# Iteration: 100%|██████████| 37/37 [00:01<00:00, 24.53it/s]]
# Iteration:  49%|████▊     | 18/37 [00:00<00:00, 31.20it/s]s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.543533  best_val_acc: 1.543533
# ====epoch 9
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 105/105 [00:02<00:00, 38.67it/s]
# Iteration:  53%|█████▎    | 90/170 [00:02<00:02, 39.28it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.871833  best_val_acc: 1.871833
# ====epoch 6
# ====Evaluation
# omit the training accuracy computation
# Iteration:   0%|          | 0/37 [00:00<?, ?it/s]35.93it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.633700  best_val_acc: 0.633700
# ====epoch 7
# Iteration: 100%|██████████| 37/37 [00:01<00:00, 25.36it/s]]]
# Iteration:  86%|████████▌ | 43/50 [00:01<00:00, 39.97it/s]s]
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.341432  best_val_acc: 1.341432
# ====epoch 4
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 24.48it/s]s]
# Iteration:  74%|███████▎  | 125/170 [00:03<00:01, 41.64it/s]
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 50/50 [00:01<00:00, 29.87it/s]
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 24.59it/s]]]
# Iteration:  80%|████████  | 136/170 [00:03<00:00, 44.14it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.601465  best_val_acc: 0.601465
# ====epoch 4
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.439209  best_val_acc: 1.439209
# ====epoch 11
# Iteration:  14%|█▎        | 5/37 [00:00<00:02, 10.69it/s]/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.898466  best_val_acc: 1.898466
# ====epoch 10
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.861789  best_val_acc: 0.861789
# ====epoch 5
# Iteration:  93%|█████████▎| 158/170 [00:04<00:00, 34.92it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.816350  best_val_acc: 1.816350
# ====epoch 7
# Iteration:  21%|██▏       | 6/28 [00:00<00:01, 13.22it/s]/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 37/37 [00:01<00:00, 20.82it/s]
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 23.54it/s]]]
# Iteration: 100%|██████████| 170/170 [00:04<00:00, 36.72it/s]
# Iteration: 100%|██████████| 105/105 [00:02<00:00, 36.33it/s]
# Iteration:  55%|█████▌    | 58/105 [00:01<00:01, 37.44it/s]]
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 37/37 [00:01<00:00, 23.02it/s]]]
# Iteration:  79%|███████▊  | 22/28 [00:00<00:00, 29.52it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.602564  best_val_acc: 0.602564
# ====epoch 8
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 22.98it/s]
# Iteration:  27%|██▋       | 149/544 [00:04<00:12, 32.88it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.575701  best_val_acc: 1.575701
# ====epoch 12
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.913881  best_val_acc: 0.913881
# ====epoch 4
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 21.86it/s]]
# Iteration:   4%|▎         | 1/28 [00:00<00:13,  2.00it/s]s]]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.498434  best_val_acc: 1.498434
# ====epoch 11
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.617949  best_val_acc: 0.617949
# ====epoch 5
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.105974  best_val_acc: 1.105974
# ====epoch 4
# Iteration: 100%|██████████| 50/50 [00:01<00:00, 25.63it/s]s]
# Iteration:  88%|████████▊ | 92/105 [00:02<00:00, 38.59it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.074437  best_val_acc: 1.074437
# ====epoch 3
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.563506  best_val_acc: 1.563506
# ====epoch 8
# Iteration:  73%|███████▎  | 27/37 [00:01<00:00, 25.56it/s]s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.033522  best_val_acc: 0.033522
# ====epoch 2
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.032513  best_val_acc: 0.032513
# ====epoch 2
# train_loss : inf val_loss: inf
# train: 0.000000 val: 3.929802  best_val_acc: 3.929802
# ====epoch 9
# Iteration: 100%|██████████| 105/105 [00:03<00:00, 30.48it/s]
# Iteration:  18%|█▊        | 19/105 [00:01<00:03, 24.76it/s]]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.896417  best_val_acc: 0.896417
# ====epoch 6
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 17.17it/s]s]
# Iteration: 100%|██████████| 37/37 [00:02<00:00, 18.16it/s]s]
# Iteration:  54%|█████▍    | 20/37 [00:01<00:00, 20.87it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 5.719185  best_val_acc: 5.719185
# ====epoch 4
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 19.54it/s]s]
# Iteration: 100%|██████████| 50/50 [00:02<00:00, 22.60it/s]]]
# Iteration: 100%|██████████| 28/28 [00:01<00:00, 19.13it/s]s]
# Iteration:  31%|███▏      | 33/105 [00:01<00:03, 22.67it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.083676  best_val_acc: 1.083676
# ====epoch 5
# ====Evaluation
# omit the training accuracy computation
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 4.203236  best_val_acc: 4.203236
# ====epoch 8
# train_loss : inf val_loss: inf
# train: 0.000000 val: 109.078831  best_val_acc: 109.078831
# ====epoch 3
# train_loss : inf val_loss: inf
# train: 0.000000 val: 104.356347  best_val_acc: 104.356347
# ====epoch 5
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.907859  best_val_acc: 0.907859
# ====epoch 4
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.845298  best_val_acc: 1.845298
# ====epoch 13
# Iteration:   0%|          | 0/37 [00:00<?, ?it/s]2.21it/s]]]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.624542  best_val_acc: 0.624542
# ====epoch 9
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 100.686746  best_val_acc: 100.686746
# ====epoch 5
# Iteration: 100%|██████████| 16/16 [00:01<00:00, 11.81it/s]]
# Iteration: 100%|██████████| 37/37 [00:02<00:00, 15.79it/s]]]
# Iteration:   6%|▌         | 30/544 [00:01<00:25, 20.12it/s]]
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 1.645009  best_val_acc: 1.645009
# ====epoch 12
# Iteration: 100%|██████████| 16/16 [00:01<00:00, 11.76it/s]
# Iteration:  44%|████▍     | 238/544 [00:07<00:12, 23.65it/s]
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.841112  best_val_acc: 0.841112
# ====epoch 5
# Iteration:   9%|▊         | 47/544 [00:02<00:19, 25.71it/s]]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 4.147569  best_val_acc: 4.147569
# ====epoch 10
# Iteration:  12%|█▏        | 6/50 [00:00<00:05,  8.13it/s]]]]
# train_loss : inf val_loss: inf
# ...
# ====Evaluation
# omit the training accuracy computation
# Iteration:  14%|█▍        | 146/1028 [00:02<00:14, 62.50it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.788862  best_val_acc: 0.788862
# ====epoch 87
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 67.52it/s]
# Iteration:  52%|█████▏    | 534/1028 [00:07<00:07, 69.67it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  62%|██████▏   | 637/1028 [00:09<00:05, 65.25it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.802099  best_val_acc: 0.802099
# ====epoch 88
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.30it/s]
# Iteration:  90%|█████████ | 929/1028 [00:13<00:01, 77.08it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 1028/1028 [00:14<00:00, 70.69it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.791057  best_val_acc: 0.791057
# ====epoch 88
# ====Evaluation
# omit the training accuracy computation
# Iteration:  46%|████▌     | 470/1028 [00:07<00:08, 64.70it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.789349  best_val_acc: 0.789349
# ====epoch 88
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.63it/s]
# Iteration:  59%|█████▊    | 603/1028 [00:08<00:06, 70.60it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  69%|██████▉   | 712/1028 [00:10<00:04, 70.50it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.797628  best_val_acc: 0.797628
# ====epoch 89
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 65.87it/s]
# Iteration:  25%|██▍       | 254/1028 [00:04<00:10, 72.72it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 1028/1028 [00:14<00:00, 70.06it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  36%|███▌      | 368/1028 [00:05<00:08, 74.25it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.786308  best_val_acc: 0.786308
# ====epoch 89
# Iteration:  39%|███▉      | 402/1028 [00:06<00:08, 72.33it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.786752  best_val_acc: 0.786752
# ====epoch 89
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 65.99it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:   0%|          | 0/1028 [00:00<?, ?it/s]75.99it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.804518  best_val_acc: 0.804518
# ====epoch 90
# Iteration: 100%|██████████| 1028/1028 [00:14<00:00, 70.07it/s]
# Iteration:  97%|█████████▋| 1000/1028 [00:15<00:00, 64.26it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.05it/s]
# Iteration:  25%|██▌       | 257/1028 [00:04<00:09, 78.89it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  30%|██▉       | 306/1028 [00:04<00:09, 76.73it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.788277  best_val_acc: 0.788277
# ====epoch 90
# Iteration:   3%|▎         | 30/1028 [00:00<00:20, 49.85it/s]]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.787708  best_val_acc: 0.787708
# ====epoch 90
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.76it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  83%|████████▎ | 855/1028 [00:12<00:02, 65.83it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.785870  best_val_acc: 0.785870
# ====epoch 91
# Iteration: 100%|██████████| 1028/1028 [00:14<00:00, 71.31it/s]
# Iteration:  91%|█████████ | 932/1028 [00:13<00:01, 69.65it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:   0%|          | 0/1028 [00:00<?, ?it/s] 63.92it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.765202  best_val_acc: 0.765202
# ====epoch 91
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 67.30it/s]
# Iteration:  11%|█         | 110/1028 [00:01<00:12, 75.68it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.773111  best_val_acc: 0.773111
# ====epoch 91
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.90it/s]
# Iteration:  62%|██████▏   | 635/1028 [00:09<00:05, 69.08it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  91%|█████████ | 935/1028 [00:13<00:01, 75.71it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.798097  best_val_acc: 0.798097
# ====epoch 92
# Iteration: 100%|██████████| 1028/1028 [00:14<00:00, 70.76it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  16%|█▋        | 168/1028 [00:02<00:12, 67.58it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.798819  best_val_acc: 0.798819
# ====epoch 92
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.75it/s]
# Iteration:   9%|▊         | 88/1028 [00:01<00:14, 65.47it/s]]
# ====Evaluation
# omit the training accuracy computation
# Iteration:   0%|          | 0/1028 [00:00<?, ?it/s]77.11it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.802178  best_val_acc: 0.802178
# ====epoch 92
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 67.11it/s]
# Iteration:  88%|████████▊ | 902/1028 [00:12<00:01, 73.15it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  99%|█████████▊| 1013/1028 [00:14<00:00, 69.20it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.786079  best_val_acc: 0.786079
# ====epoch 93
# Iteration: 100%|██████████| 1028/1028 [00:14<00:00, 70.60it/s]
# Iteration:   1%|▏         | 14/1028 [00:00<00:29, 34.94it/s]]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  85%|████████▍ | 870/1028 [00:13<00:02, 67.03it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.779930  best_val_acc: 0.779930
# ====epoch 93
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.20it/s]
# Iteration:  16%|█▋        | 168/1028 [00:02<00:11, 72.54it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  28%|██▊       | 284/1028 [00:04<00:09, 76.03it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.790127  best_val_acc: 0.790127
# ====epoch 93
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 67.26it/s]
# Iteration:  94%|█████████▍| 969/1028 [00:13<00:00, 74.54it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 1028/1028 [00:14<00:00, 70.67it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  71%|███████▏  | 735/1028 [00:11<00:03, 77.54it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.802628  best_val_acc: 0.802628
# ====epoch 94
# Iteration:  78%|███████▊  | 803/1028 [00:12<00:03, 69.08it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.793688  best_val_acc: 0.793688
# ====epoch 94
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.79it/s]
# Iteration:  27%|██▋       | 277/1028 [00:04<00:10, 69.73it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  34%|███▍      | 349/1028 [00:05<00:10, 66.62it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.786556  best_val_acc: 0.786556
# ====epoch 94
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.65it/s]
# Iteration:  99%|█████████▉| 1022/1028 [00:14<00:00, 73.65it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 1028/1028 [00:14<00:00, 69.33it/s]
# Iteration:  62%|██████▏   | 637/1028 [00:09<00:05, 76.70it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:   0%|          | 0/1028 [00:00<?, ?it/s]76.66it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.796639  best_val_acc: 0.796639
# ====epoch 95
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.792637  best_val_acc: 0.792637
# ====epoch 95
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.45it/s]
# Iteration:  29%|██▉       | 297/1028 [00:04<00:10, 67.86it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  39%|███▉      | 402/1028 [00:05<00:08, 70.68it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.794741  best_val_acc: 0.794741
# ====epoch 95
# Iteration: 100%|██████████| 1028/1028 [00:14<00:00, 70.55it/s]
# Iteration:  97%|█████████▋| 996/1028 [00:14<00:00, 65.51it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.76it/s]
# Iteration:  60%|█████▉    | 615/1028 [00:09<00:05, 70.21it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  65%|██████▍   | 667/1028 [00:10<00:04, 74.95it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.798562  best_val_acc: 0.798562
# ====epoch 96
# Iteration:   0%|          | 0/1028 [00:00<?, ?it/s]8.74it/s]]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.788482  best_val_acc: 0.788482
# ====epoch 96
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.47it/s]
# Iteration:  37%|███▋      | 377/1028 [00:05<00:08, 74.84it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  47%|████▋     | 484/1028 [00:06<00:07, 72.97it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.762857  best_val_acc: 0.762857
# ====epoch 96
# Iteration: 100%|██████████| 1028/1028 [00:14<00:00, 71.04it/s]
# Iteration:  90%|████████▉ | 922/1028 [00:13<00:01, 66.19it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  98%|█████████▊| 1010/1028 [00:15<00:00, 67.82it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.784877  best_val_acc: 0.784877
# ====epoch 97
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.44it/s]
# Iteration:   2%|▏         | 18/1028 [00:00<00:24, 42.00it/s]]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  12%|█▏        | 125/1028 [00:02<00:12, 70.69it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.798755  best_val_acc: 0.798755
# ====epoch 97
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 67.05it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:   0%|          | 0/1028 [00:00<?, ?it/s]71.15it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.790322  best_val_acc: 0.790322
# ====epoch 97
# Iteration: 100%|██████████| 1028/1028 [00:14<00:00, 71.17it/s]
# Iteration:  41%|████      | 422/1028 [00:06<00:09, 64.69it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  50%|████▉     | 509/1028 [00:07<00:08, 63.76it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.767747  best_val_acc: 0.767747
# ====epoch 98
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.84it/s]
# Iteration:  60%|██████    | 617/1028 [00:09<00:05, 75.93it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  20%|██        | 207/1028 [00:03<00:11, 72.42it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.780742  best_val_acc: 0.780742
# ====epoch 98
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.84it/s]
# Iteration:  51%|█████     | 521/1028 [00:07<00:07, 72.40it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  62%|██████▏   | 637/1028 [00:09<00:05, 74.03it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.772787  best_val_acc: 0.772787
# ====epoch 98
# Iteration: 100%|██████████| 1028/1028 [00:14<00:00, 69.73it/s]
# Iteration:  34%|███▍      | 352/1028 [00:05<00:10, 62.02it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  43%|████▎     | 438/1028 [00:07<00:08, 66.00it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.796526  best_val_acc: 0.796526
# ====epoch 99
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.58it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:   0%|          | 0/1028 [00:00<?, ?it/s]75.43it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.797971  best_val_acc: 0.797971
# ====epoch 99
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 65.52it/s]
# Iteration:  60%|█████▉    | 612/1028 [00:08<00:06, 69.16it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  71%|███████   | 725/1028 [00:10<00:04, 73.05it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.765591  best_val_acc: 0.765591
# ====epoch 99
# Iteration: 100%|██████████| 1028/1028 [00:14<00:00, 70.47it/s]
# Iteration:  70%|███████   | 722/1028 [00:10<00:04, 64.33it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  79%|███████▉  | 814/1028 [00:12<00:03, 65.58it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.790368  best_val_acc: 0.790368
# ====epoch 100
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 67.03it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  33%|███▎      | 340/1028 [00:05<00:09, 75.13it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.796211  best_val_acc: 0.796211
# ====epoch 100
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.68it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:   0%|          | 0/1028 [00:00<?, ?it/s]75.03it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.791673  best_val_acc: 0.791673
# ====epoch 100
# Iteration: 100%|██████████| 1028/1028 [00:14<00:00, 69.53it/s]
# Iteration:  65%|██████▌   | 669/1028 [00:10<00:05, 65.78it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  30%|███       | 310/1028 [00:05<00:11, 63.21it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.786079  best_val_acc: 0.786079
# Loaded trained model with success.
# Iteration:  39%|███▊      | 398/1028 [00:06<00:09, 64.95it/s]
# test auc, test_loss : 0.7454354081770602 tensor(0.0166, device='cuda:0', dtype=torch.float64)
# Extracted ratio: 0.25
# Iteration: 100%|██████████| 1028/1028 [00:15<00:00, 66.78it/s]
# ====Evaluation
# omit the training accuracy computation
# Iteration:  68%|██████▊   | 698/1028 [00:10<00:04, 79.38it/s]
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.807319  best_val_acc: 0.807319
# Loaded trained model with success.
# Iteration:  80%|████████  | 823/1028 [00:12<00:02, 80.30it/s]
# test auc, test_loss : 0.7626392939222465 tensor(0.0308, device='cuda:1', dtype=torch.float64)
# Extracted ratio: 0.25
# Iteration: 100%|██████████| 1028/1028 [00:14<00:00, 70.54it/s]
# ====Evaluation
# omit the training accuracy computation
# train_loss : inf val_loss: inf
# train: 0.000000 val: 0.786544  best_val_acc: 0.786544
# Loaded trained model with success.
# test auc, test_loss : 0.7672241642364664 tensor(0.0176, device='cuda:1', dtype=torch.float64)
# Extracted ratio: 0.25
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[2], line 45
#      43 # 결과 대기
#      44 for future in futures:
# ---> 45     future.result()
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /opt/conda/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# Cell In[2], line 31, in run_script(script, dataset, seed, device)
#      28 os.chdir('/tf/GraphMAE-pyg - copy/chem')
#      30 # subprocess를 사용하여 명령어 실행실행
# ---> 31 subprocess.run(command, check=True)
#
# File /opt/conda/lib/python3.10/subprocess.py:526, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     524     retcode = process.poll()
#     525     if check and retcode:
# --> 526         raise CalledProcessError(retcode, process.args,
#     527                                  output=stdout, stderr=stderr)
#     528 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['python', 'pretrain2+finetune-edgeRemoval.py', '--dataset', 'clintox', '--device', '0', '--seed', '789', '--input_model_file', './pretrain2/edgeRemoval/zinc_standard_agent_gin_0.25_42/model.pth']' returned non-zero exit status 1.
